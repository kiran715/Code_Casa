# %% [markdown]
# IMPORTING THE LIBRARIES AND LOADING THE DATASET

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599  \
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539  \
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# STATISTICAL ANALYSIS

# %%
df.describe().T
# Out:
#            count          mean           std         min           25%
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000  \
# V1      284807.0  1.168375e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  3.416908e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -1.379537e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.074095e-15      1.415869   -5.683171     -0.848640
# V5      284807.0  9.604066e-16      1.380247 -113.743307     -0.691597
# V6      284807.0  1.487313e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -5.556467e-16      1.237094  -43.557242     -0.554076
# V8      284807.0  1.213481e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -2.406331e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  2.239053e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  1.673327e-15      1.020713   -4.797473     -0.762494
# ...

# %%
df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# REMOVING OUTLIERS USING QUANTILE METHOD

# %%
def remove_outliers(col):
    min_thresold,max_thresold = df[col].quantile([0.01,0.999]) 
    return min_thresold,max_thresold
for col_name in df.iloc[:,1:29].columns:
    lower_limit,upper_limit = remove_outliers(col_name)
    df[col_name] = np.where(df[col_name] > upper_limit,upper_limit,np.where(df[col_name] < lower_limit,lower_limit,df[col_name]))

# %%
df.describe().T
# Out:
#            count          mean           std       min           25%
# Time    284807.0  94813.859575  47488.145955  0.000000  54201.500000  \
# V1      284807.0      0.038657      1.712971 -6.563172     -0.920373
# V2      284807.0      0.038491      1.337464 -4.960296     -0.598550
# V3      284807.0      0.024652      1.376327 -3.978369     -0.890365
# V4      284807.0      0.002478      1.392071 -3.122980     -0.848640
# V5      284807.0      0.021200      1.187091 -3.060375     -0.691597
# V6      284807.0      0.010583      1.262574 -2.124017     -0.768296
# V7      284807.0      0.020991      0.986510 -3.012821     -0.554076
# V8      284807.0      0.036793      0.815897 -4.033894     -0.208630
# V9      284807.0      0.003356      1.077663 -2.455284     -0.643098
# V10     284807.0      0.011031      1.009855 -2.092669     -0.535426
# V11     284807.0      0.000688      1.000889 -2.093077     -0.762494
# V12     284807.0      0.010163      0.929837 -3.063933     -0.405571
# ...

# %%
df["Class"].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
non_fraud = df[df["Class"]==0] #0 -> non fradulent
fraud = df[df["Class"]==1] # 1 -> fradulent

# %%
non_fraud.Amount.describe().T
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe().T
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [markdown]
# UNDERSMAPLING THE DATA SINCE THE DATA WAS UNBALANCED

# %%
Non_fraud = non_fraud.sample(n=492)
data = pd.concat([Non_fraud,fraud],axis=0)

# %%
data["Class"].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
x = data.drop(["Class"],axis=1)
y = data["Class"]
x.shape,y.shape
# Out:
# ((984, 30), (984,))

# %% [markdown]
# SPLITTING THE DATA FOR TRAIN AND TEST

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2,random_state=2,stratify=y)
print(X_train.shape,X_test.shape,Y_train.shape,Y_test.shape)
# Out:
# (787, 30) (197, 30) (787,) (197,)

# %%
MODEL SELECTRION AND TRAINING

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# C:\Users\X\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# CHECKING ACCURACY ON TRAINING DATA

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
X_train_predict = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_predict, Y_train)
print("Accuracy on train data : ",training_data_accuracy)
# Out:
# Accuracy on train data :  0.951715374841169

# %%
CHECKING ACCURACY ON TEST DATA

# %%
X_test_predict = model.predict(X_test)
testing_data_accuracy = accuracy_score(X_test_predict, Y_test)
print("Accuracy on test data : ",testing_data_accuracy)
# Out:
# Accuracy on test data :  0.949238578680203

# %% [markdown]
# VISUALIZING THE CONFUSION MATRIX

# %%
import seaborn as sns
import matplotlib.pyplot as plt
cm_train = confusion_matrix(X_train_predict, Y_train)
sns.heatmap(cm_train,annot=True,fmt='g',xticklabels=['Not fraud','fraud'],yticklabels=['Not fraud','fraud'])
plt.xlabel('Actual',fontsize=12)
plt.ylabel('Prediction',fontsize=12)
plt.title('Confusion Matrix for Train data',fontsize=20)
plt.show()

# %%
cm_test = confusion_matrix(X_test_predict, Y_test)
sns.heatmap(cm_test,annot=True,fmt='g',xticklabels=['Not fraud','fraud'],yticklabels=['Not fraud','fraud'])
plt.xlabel('Actual',fontsize=12)
plt.ylabel('Prediction',fontsize=12)
plt.title('Confusion Matrix for Test data',fontsize=20)
plt.show()
